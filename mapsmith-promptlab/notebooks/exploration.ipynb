# %% [markdown]
# # MapSmith - Exploration Notebook
#
# This notebook is reserved for exploratory analysis, testing, and experimentation.
#
# Use it to:
# - Test prompt generation
# - Analyze evaluation results
# - Prototype new ideas
# - Visualize data

# %%
# Imports and setup
import sys
sys.path.insert(0, '../src')

# Import project modules here as needed
